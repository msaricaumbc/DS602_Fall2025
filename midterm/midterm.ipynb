# %% [markdown]
# # Midterm

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Option 1

# %%
df_a = pd.read_csv('employee_departure_dataset.csv')

# %%
df_a.head()
# Out:
#    Unnamed: 0  RecordId  Gender  Distance  YearsWorked  TrainingHours  \
# 0           0   1002332       1  >30miles            8             45
# 1           1   1002333       0  ~10miles            7             73
# 2           2   1002334       0    <5mile            6             65
# 3           3   1002335       0  ~15miles            7             18
# 4           4   1002336       1  ~20miles            7             73
#
#    WorkLifeBalance  NumOfProjects  JobInvolvement  TeamSize  ...  \
# 0                1             18               3        10  ...
# 1                5              7               5        19  ...
# 2                1             13               2         7  ...
# 3                4             14               3         3  ...
# 4                5             10               1        18  ...
#
#    WorkSatisfactionScore  JobEngagementScore  PhysicalActivityScore  \
# 0                      1                   5                      3
# 1                      7                   9                      3
# 2                      8                   4                      3
# 3                      3                   4                      4
# 4                      5                   1                      6
#
#    MentalWellbeingScore  PreviousSalary  Salary  SelfReview  SupervisorReview  \
# 0                     1             59K     60K         4.0               5.0
# 1                     7             61K     64K         4.0               4.0
# 2                     1             61K     63K         4.0               4.0
# 3                     5             58K     61K         5.0               5.0
# 4                     3             61K     62K         5.0               5.0
#
#    DepartmentCode  Left
# 0               2     0
# 1               2     0
# 2               3     0
# 3               7     0
# 4               5     0
#
# [5 rows x 31 columns]

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               300000 non-null  int64
#  1   RecordId                 300000 non-null  int64
#  2   Gender                   300000 non-null  int64
#  3   Distance                 299734 non-null  object
#  4   YearsWorked              300000 non-null  int64
#  5   TrainingHours            300000 non-null  int64
#  6   WorkLifeBalance          300000 non-null  int64
#  7   NumOfProjects            300000 non-null  int64
#  8   JobInvolvement           300000 non-null  int64
#  9   TeamSize                 300000 non-null  int64
#  10  MentorshipReceived       300000 non-null  int64
#  11  TechSkillLevel           300000 non-null  int64
#  12  AttendanceRate           300000 non-null  float64
#  13  StressLevel              300000 non-null  int64
#  14  PeerFeedbackScore        300000 non-null  int64
#  15  AnnualLeaveDays          300000 non-null  int64
#  16  Dependents               300000 non-null  int64
#  17  Certifications           300000 non-null  int64
#  18  OnsiteOpportunities      300000 non-null  int64
#  19  SkillDevelopmentCourses  300000 non-null  int64
#  20  ProjectComplexity        300000 non-null  int64
#  21  WorkSatisfactionScore    300000 non-null  int64
#  22  JobEngagementScore       300000 non-null  int64
#  23  PhysicalActivityScore    300000 non-null  int64
#  24  MentalWellbeingScore     300000 non-null  int64
#  25  PreviousSalary           300000 non-null  object
#  26  Salary                   300000 non-null  object
#  27  SelfReview               299404 non-null  float64
#  28  SupervisorReview         299423 non-null  float64
#  29  DepartmentCode           300000 non-null  int64
#  30  Left                     300000 non-null  int64
# dtypes: float64(3), int64(25), object(3)
# memory usage: 71.0+ MB

# %%
df_a.Left.hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Option 2

# %%
df = pd.read_csv('anomaly_detection.csv')
df.date = pd.to_datetime(df.date)

df.head()
# Out:
#         date  value agency  anomaly
# 0 2020-01-01    197    AAA        0
# 1 2020-01-01    404    CCC        0
# 2 2020-01-01    153    BBB        0
# 3 2020-01-02    205    AAA        0
# 4 2020-01-02    401    CCC        0

# %%
df.query('anomaly == 1')
# Out:
#            date  value agency  anomaly
# 24   2020-01-09    167    BBB        1
# 25   2020-01-09    411    CCC        1
# 26   2020-01-09    222    AAA        1
# 30   2020-01-11    390    CCC        1
# 31   2020-01-11    143    BBB        1
# ...         ...    ...    ...      ...
# 5557 2025-01-26    346    AAA        1
# 5558 2025-01-26    194    BBB        1
# 5562 2025-01-28    186    BBB        1
# 5563 2025-01-28    255    CCC        1
# 5564 2025-01-28    336    AAA        1
#
# [2529 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5574 entries, 0 to 5573
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     5574 non-null   datetime64[ns]
#  1   value    5574 non-null   int64
#  2   agency   5574 non-null   object
#  3   anomaly  5574 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 174.3+ KB

# %%
sns.scatterplot(data=df, x='date', y='value', hue='agency')
# Out:
# <Axes: xlabel='date', ylabel='value'>

# %%
sns.scatterplot(data=df.query("agency=='CCC'"), x='date', y='value', hue='anomaly')
# Out:
# <Axes: xlabel='date', ylabel='value'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5574 entries, 0 to 5573
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     5574 non-null   datetime64[ns]
#  1   value    5574 non-null   int64
#  2   agency   5574 non-null   object
#  3   anomaly  5574 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 174.3+ KB
